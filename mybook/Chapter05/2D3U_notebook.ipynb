# %%
import nglview as nv

    "view = nv.show_pdbid(\"2D3U\")  # RCSB PDB에서 \"2D3U\"를 로드하고 뷰어 위젯을 표시합니다\n",
# view = nv.show_file("2D3U.pdb")
view.representations = [
    {"type": "cartoon", "params": {"sele": "protein", "color": "residueindex"}},
    {"type": "ball+stick", "params": {"sele": "ligand"}},
]

view
# Out:
# NGLWidget()

# %% [markdown]
# Github은 nglview 렌더링을 지원하지 않으므로, 결과 스크린샷을 업로드합니다.
# ![](https://i.imgur.com/QPaxFNU.png)
